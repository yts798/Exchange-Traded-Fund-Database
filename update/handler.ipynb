# %%
# !python crawler_ezj.py
# Out:
# {'status': 0, 'count': 756, 'rows': {'item': [{'name': '沪深300ETF', 'code': '510300', 'close': 3.812, 'rate': 9914, 'premium': 9979, 'tag': '宽基，大盘股', 'mtexp': '0.60%', 'fundfirm': '华泰柏瑞基金', 'listdate': '2012-05-28', 'index': '沪深300指数', 'avgamount': 232404.12, 'm1': 9509, 'y0': 9832, 'y1': 9457, 'y3': 9953, 'y5': 10723, 'scale': 670.98}, {'name': '纳指ETF', 'code': '513100', 'close': 1.05, 'rate': 10019, 'premium': 10038, 'tag': '跨境，美国', 'mtexp': '0.80%', 'fundfirm': '国泰基金', 'listdate': '2013-05-15', 'index': '纳斯达克100指数', 'avgamount': 36268.24, 'm1': 11463, 'y0': 13141, 'y1': 12209, 'y3': 13845, 'y5': 21748, 'scale': 62.11}, {'name': '科创50ETF', 'code': '588000', 'close': 1.07, 'rate': 9763, 'premium': 10019, 'tag': '宽基，中小盘，科创板', 'mtexp': '0.60%', 'fundfirm': '华夏基金', 'listdate': '2020-11-16', 'index': '科创50指数', 'avgamount': 255019.48, 'm1': 9790, 'y0': 10668, 'y1': 9503, 'y3': '10000', 'y5': '10000', 'scale': 560.59}, {'name': '半导体ETF', 'code': '512480', 'close': 0.917, 'rate': 9704, 'pre
# ...
