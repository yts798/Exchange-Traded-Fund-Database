# %%
# !python crawler_ezj.py
# Out:
# {'status': 0, 'count': 766, 'rows': {'item': [{'name': '纳指ETF', 'code': '513100', 'close': 1.142, 'rate': 10088, 'premium': 10000, 'tag': '跨境，美国', 'mtexp': '0.80%', 'fundfirm': '国泰基金', 'listdate': '2013-05-15', 'index': '纳斯达克100指数', 'avgamount': 43707.3, 'm1': 10382, 'y0': 14293, 'y1': 13910, 'y3': 14762, 'y5': 22313, 'scale': 62.11}, {'name': '沪深300ETF', 'code': '510300', 'close': 3.918, 'rate': 9985, 'premium': 10008, 'tag': '宽基，大盘股', 'mtexp': '0.60%', 'fundfirm': '华泰柏瑞基金', 'listdate': '2012-05-28', 'index': '沪深300指数', 'avgamount': 160302.84, 'm1': 9847, 'y0': 10105, 'y1': 9265, 'y3': 8892, 'y5': 12121, 'scale': 670.98}, {'name': '通信ETF', 'code': '515880', 'close': 1.276, 'rate': 9733, 'premium': 9992, 'tag': '行业，TMT，通信', 'mtexp': '0.60%', 'fundfirm': '国泰基金', 'listdate': '2019-09-06', 'index': '通信设备指数', 'avgamount': 29066.14, 'm1': 9891, 'y0': 15504, 'y1': 14068, 'y3': 10511, 'y5': '10000', 'scale': 19.35}, {'name': '酒ETF', 'code': '512690', 'close': 0.782, 'rate': 9962, 'premium': 10006, 'tag': '行业，食品饮料，酒', 'mtexp': '0.60%', 'fundfirm': '鹏华基金', 'listdate': '2019-05-06', 'index': '中证酒指数', 'avgamount': 61209.47, 'm1': 9422, 'y0': 9200, 'y1': 9030, 'y3': 12613, 'y5': '10000', 'scale': 122.16}, {'name': '科创50ETF', 'code': '588000', 'close': 1.025, 'rate': 9971, 'premium': 10005, 'tag': '宽基，中小盘，科创板', 'mtexp': '0.60%', 'fundfirm': '华夏基金', 'listdate': '2020-11-16', 'index': '科创50指数', 'avgamount': 208124.61, 'm1': 9335, 'y0': 10219, 'y1': 9144, 'y3': '10000', 'y5': '10000', 'scale': 560.59}, {'name': '豆粕ETF', 'code': '159985', 'close': 2.059, 'rate': 10015, 'premium': 10000, 'tag': '商品，农产品', 'mtexp': '0.60%', 'fundfirm': '华夏基金', 'listdate': '2019-12-05', 'index': '大商所豆粕期货价格指数', 'avgamount': 9122.32, 'm1': 11112, 'y0': 10244, 'y1': 13344, 'y3': 20386, 'y5': '10000', 'scale': 5.53}, {'name': '光伏ETF', 'code': '515790', 'close': 1.199, 'rate': 9917, 'premium': 10023, 'tag': '主题，光伏，新兴产业', 'mtexp': '0.60%', 'fundfirm': '华泰柏瑞基金', 'listdate': '2020-12-18', 'index': '光伏产业指数', 'avgamount': 57671.18, 'm1': 9828, 'y0': 8726, 'y1': 6836, 'y3': '10000', 'y5': '10000', 'scale': 167.47}, {'name': '医疗ETF', 'code': '512170', 'close': 0.416, 'rate': 9976, 'premium': 10005, 'tag': '行业，医药', 'mtexp': '0.60%', 'fundfirm': '华宝基金', 'listdate': '2019-06-17', 'index': '中证医疗指数', 'avgamount': 43814.78, 'm1': 9327, 'y0': 8189, 'y1': 7376, 'y3': 5853, 'y5': '10000', 'scale': 190.7}, {'name': '创业板ETF', 'code': '159915', 'close': 2.147, 'rate': 9977, 'premium': 10000, 'tag': '宽基，中小盘', 'mtexp': '0.60%', 'fundfirm': '易方达基金', 'listdate': '2011-12-09', 'index': '创业板指', 'avgamount': 103701.9, 'm1': 9724, 'y0': 9421, 'y1': 8011, 'y3': 8312, 'y5': 13914, 'scale': 336.25}, {'name': '创业板50ETF', 'code': '159949', 'close': 0.934, 'rate': 9968, 'premium': 9998, 'tag': '宽基，中小盘', 'mtexp': '0.60%', 'fundfirm': '华安基金', 'listdate': '2016-07-22', 'index': '创业板50指数', 'avgamount': 41472.79, 'm1': 9699, 'y0': 9077, 'y1': 7668, 'y3': 8964, 'y5': 15750, 'scale': 175.46}, {'name': '中概互联网ETF', 'code': '513050', 'close': 1.029, 'rate': 9913, 'premium': 10000, 'tag': '跨境，中概股', 'mtexp': '0.85%', 'fundfirm': '易方达基金', 'listdate': '2017-01-18', 'index': '中国互联网50指数', 'avgamount': 89370.28, 'm1': 9563, 'y0': 9885, 'y1': 9519, 'y3': 5419, 'y5': 6779, 'scale': 384.27}, {'name': '半导体ETF', 'code': '512480', 'close': 0.913, 'rate': 10011, 'premium': 10003, 'tag': '行业，半导体，芯片', 'mtexp': '0.60%', 'fundfirm': '国联安基金', 'listdate': '2019-06-12', 'index': '半导体指数', 'avgamount': 141445.09, 'm1': 9702, 'y0': 11080, 'y1': 9807, 'y3': 8236, 'y5': '10000', 'scale': 194.83}, {'name': '游戏ETF', 'code': '159869', 'close': 1.272, 'rate': 9860, 'premium': 10009, 'tag': '主题，游戏', 'mtexp': '0.60%', 'fundfirm': '华夏基金', 'listdate': '2021-03-05', 'index': '动漫游戏指数', 'avgamount': 62930.37, 'm1': 7925, 'y0': 16671, 'y1': 16825, 'y3': '10000', 'y5': '10000', 'scale': 14.37}, {'name': '军工ETF', 'code': '512660', 'close': 1.1, 'rate': 10009, 'premium': 10003, 'tag': '行业，军工', 'mtexp': '0.60%', 'fundfirm': '国泰基金', 'listdate': '2016-08 ...
# ose': 1.019, 'rate': 9941, 'premium': 10025, 'tag': '主题，新兴产业，新能源', 'mtexp': '0.60%', 'fundfirm': '华夏基金', 'listdate': '2021-03-19', 'index': '中证新能指数', 'avgamount': 169.9, 'm1': 9779, 'y0': 8665, 'y1': 6381, 'y3': '10000', 'y5': '10000', 'scale': 0.886}, {'name': '畜牧养殖ETF', 'code': '516670', 'close': 0.762, 'rate': 10079, 'premium': 10001, 'tag': '行业，畜牧养殖', 'mtexp': '0.30%', 'fundfirm': '招商基金', 'listdate': '2021-03-26', 'index': '中证畜牧指数', 'avgamount': 3396.22, 'm1': 10242, 'y0': 9115, 'y1': 8202, 'y3': '10000', 'y5': '10000', 'scale': 5.13}, {'name': '云计算沪港深ETF', 'code': '517390', 'close': 0.994, 'rate': 9793, 'premium': 10010, 'tag': '跨境，香港，云计算', 'mtexp': '0.60%', 'fundfirm': '天弘基金', 'listdate': '2021-12-23', 'index': 'SHS云计算人民币指数', 'avgamount': 499.7, 'm1': 8899, 'y0': 12842, 'y1': 14079, 'y3': '10000', 'y5': '10000', 'scale': 0.543}, {'name': '恒生科技ETF华安', 'code': '513580', 'close': 0.563, 'rate': 10000, 'premium': 10000, 'tag': '跨境，香港，科技', 'mtexp': '0.60%', 'fundfirm': '华安基金', 'listdate': '2021-05-27', 'index': '恒生科技指数', 'avgamount': 12228.21, 'm1': 9825, 'y0': 10218, 'y1': 9757, 'y3': '10000', 'y5': '10000', 'scale': 14.72}, {'name': '港股通科技30ETF', 'code': '159636', 'close': 0.845, 'rate': 9929, 'premium': 10048, 'tag': '跨境，香港，科技', 'mtexp': '0.52%', 'fundfirm': '工银瑞信基金', 'listdate': '2022-07-20', 'index': '港股通科技指数', 'avgamount': 2381.49, 'm1': 9494, 'y0': 9215, 'y1': '10000', 'y3': '10000', 'y5': '10000', 'scale': 19.33}, {'name': '政金债5年ETF', 'code': '511580', 'close': 102.847, 'rate': 10006, 'premium': 9996, 'tag': '债券，利率债，政金债', 'mtexp': '0.20%', 'fundfirm': '招商基金', 'listdate': '2022-12-14', 'index': '政金债3-5指数', 'avgamount': 20895.87, 'm1': 10050, 'y0': 10242, 'y1': '10000', 'y3': '10000', 'y5': '10000', 'scale': 1.86}, {'name': '化工龙头ETF', 'code': '516220', 'close': 0.752, 'rate': 10094, 'premium': 10000, 'tag': '行业，化工', 'mtexp': '0.60%', 'fundfirm': '国泰基金', 'listdate': '2021-03-10', 'index': '细分化工指数', 'avgamount': 3300.87, 'm1': 10094, 'y0': 9216, 'y1': 7666, 'y3': '10000', 'y5': '10000', 'scale': 1.98}, {'name': '稀土ETF', 'code': '159713', 'close': 0.77, 'rate': 10039, 'premium': 9996, 'tag': '主题，稀土', 'mtexp': '0.60%', 'fundfirm': '富国基金', 'listdate': '2021-08-16', 'index': '稀土产业指数', 'avgamount': 3715.25, 'm1': 10052, 'y0': 9910, 'y1': 8165, 'y3': '10000', 'y5': '10000', 'scale': 2.8}, {'name': '恒生指数ETF', 'code': '513600', 'close': 2.127, 'rate': 9995, 'premium': 10000, 'tag': '跨境，香港', 'mtexp': '0.60%', 'fundfirm': '南方基金', 'listdate': '2015-01-26', 'index': '香港恒生指数', 'avgamount': 3003.59, 'm1': 9607, 'y0': 10009, 'y1': 10365, 'y3': 8464, 'y5': 8457, 'scale': 6.11}, {'name': '生物药ETF', 'code': '159839', 'close': 0.444, 'rate': 10068, 'premium': 10016, 'tag': '主题，新兴产业，生物科技', 'mtexp': '0.60%', 'fundfirm': '汇添富基金', 'listdate': '2021-02-22', 'index': '生物医药指数', 'avgamount': 1806.04, 'm1': 9569, 'y0': 7929, 'y1': 6820, 'y3': '10000', 'y5': '10000', 'scale': 5.24}, {'name': '化工ETF', 'code': '516020', 'close': 0.712, 'rate': 10085, 'premium': 9999, 'tag': '行业，化工', 'mtexp': '0.60%', 'fundfirm': '华宝基金', 'listdate': '2021-03-08', 'index': '细分化工指数', 'avgamount': 2834.39, 'm1': 10071, 'y0': 9152, 'y1': 7615, 'y3': '10000', 'y5': '10000', 'scale': 5.78}, {'name': '新能源ETF', 'code': '159875', 'close': 0.659, 'rate': 9925, 'premium': 10008, 'tag': '主题，新兴产业，新能源', 'mtexp': '0.60%', 'fundfirm': '嘉实基金', 'listdate': '2021-08-17', 'index': '中证新能指数', 'avgamount': 5861.06, 'm1': 9777, 'y0': 8717, 'y1': 6429, 'y3': '10000', 'y5': '10000', 'scale': 7.76}, {'name': '创业板ETF博时', 'code': '159908', 'close': 2.002, 'rate': 9985, 'premium': 10010, 'tag': '宽基，中小盘', 'mtexp': '0.60%', 'fundfirm': '博时基金', 'listdate': '2011-07-13', 'index': '创业板指', 'avgamount': 981.49, 'm1': 9733, 'y0': 9426, 'y1': 8024, 'y3': 8750, 'y5': 13373, 'scale': 14.26}, {'name': '可持续发展ETF', 'code': '515090', 'close': 1.152, 'rate': 9991, 'premium': 10010, 'tag': '主题，ESG', 'mtexp': '0.60%', 'fundfirm': '博时基金', 'listdate': '2020-02-20', 'index': '持续发展指数', 'avgamount': 429.66, 'm1': 9779, 'y0 ...

# %%
# !python crawler_jsl.py

# %%
# !python sw_crawler.py
# Out:
# <Response [508]>
# Traceback (most recent call last):
#   File "sw_crawler.py", line 77, in <module>
#     data = data_response.json()
#   File "/Users/sunyutong/anaconda3/lib/python3.8/site-packages/requests/models.py", line 898, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/Users/sunyutong/anaconda3/lib/python3.8/json/__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "/Users/sunyutong/anaconda3/lib/python3.8/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/Users/sunyutong/anaconda3/lib/python3.8/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# 数据
dates = ['2023-02-06', '2023-02-13', '2023-02-20', '2023-02-27']

data = {'120412.SZ': [[110.02,34.12], [114.02,43.12], [118.02,45.12], [108.02,38.12]],
        '114125.SH': [[115.02,36.15], [117.99,22.13], [135.02,39.52], [110.02,32.42]],
        '112799.SH': [[123.02,24.43], [127.95,26.18], [132.02,30.12], [139.02,22.48]], 
        '128901.SZ': [[135.02,25.01], [125.99,22.43], [138.02,27.36], [113.02,32.62]],
       }
# 题
# 给出时间数据，dates，给出可转债时间序列数据字典，key为可转债代码，value为时间序列数据
# 对于时间序列数据，条元素对应dates的时间，且每条元素格式为【收盘价，转股溢价率】
# 双低策略定义为。。。，选双低前二作为持仓！
# 求出双低策略下，每个日期的选股，以及四个交易日后的最终收益 （也可考每周收益）

# 我写一下

# 一行提取四个转债代码
codes = data.keys()
sum_profit_deng = 0
sum_profit_jia = 0
previous=[]
for date_no in range(len(dates)):
    # 当前交易日选股
    choose = []


    # 选出双低最低的
    
    # 设置一个高的双低值
    low_price_1 = 200
    low_code_1 = 'no1'
    
    for code in codes:
        re = data[code][date_no][0] + data[code][date_no][1]
        if re < low_price_1:
            low_price_1 = re
            low_code_1 = code
            
    # 选出双低第二低的
    # 设置一个高的双低值
    low_price_2 = 200
    low_code_2 = 'no2'
    for code in codes:
        re = data[code][date_no][0] + data[code][date_no][1]
        if code != low_code_1 and re < low_price_2:
            low_price_2 = re
            low_code_2 = code 
      
    # 这里就选好股了
    choose = [low_code_1,low_code_2]
    print('选股', dates[date_no], choose[0], round(low_price_1,2), choose[1], round(low_price_2,2))
    

    # 我这里写了两种做法，等权和加权，我觉得没必要逼人写出某一种，随便写，只要是等权和加权之一就行
    if date_no >= 1:
        # 加权，价格高权重大
        current_price = 0
        last_price = 0
        for code in previous:
            current_price += data[code][date_no][0]
            last_price += data[code][date_no-1][0]
            
        profit_jia = current_price/last_price - 1
        
        sum_profit_jia += profit_jia
        
        # 等权，每个权重一样
        profit_deng = 0
        
        for code in previous:
            profit_deng += (data[code][date_no][0]/data[code][date_no-1][0]-1)
            
        profit_deng /= 2
        
        sum_profit_deng += profit_deng
        
        print('收益统计', dates[date_no])
        print('等权持仓','单周收益', round(profit_deng*100,2),'%')
        print('加权持仓','单周收益', round(profit_jia*100,2),'%')
        print('等权持仓','累计收益', round(sum_profit_deng*100,2),'%')
        print('加权持仓','累计收益', round(sum_profit_jia*100,2),'%')        
        
        
        
    # 记录上个交易日选股
    previous = choose.copy()
# Out:
# 选股 2023-02-06 120412.SZ 144.14 112799.SH 147.45
# 选股 2023-02-13 114125.SH 140.12 128901.SZ 148.42
# 收益统计 2023-02-13
# 等权持仓 单周收益 3.82 %
# 加权持仓 单周收益 3.83 %
# 等权持仓 累计收益 3.82 %
# 加权持仓 累计收益 3.83 %
# 选股 2023-02-20 112799.SH 162.14 120412.SZ 163.14
# 收益统计 2023-02-20
# 等权持仓 单周收益 11.99 %
# 加权持仓 单周收益 11.91 %
# 等权持仓 累计收益 15.81 %
# 加权持仓 累计收益 15.74 %
# 选股 2023-02-27 114125.SH 142.44 128901.SZ 145.64
# 收益统计 2023-02-27
# 等权持仓 单周收益 -1.59 %
# 加权持仓 单周收益 -1.2 %
# 等权持仓 累计收益 14.23 %
# 加权持仓 累计收益 14.54 %

# %%
# 数据
dates = ['2023-02-06', '2023-02-13', '2023-02-20', '2023-02-27']

data = {'120412.SZ': [[110.02,34.12], [114.02,43.12], [118.02,45.12], [108.02,38.12]],
        '114125.SH': [[115.02,36.15], [117.99,22.13], [135.02,39.52], [110.02,32.42]],
        '112799.SH': [[123.02,24.43], [127.95,26.18], [132.02,30.12], [139.02,22.48]], 
        '128901.SZ': [[135.02,25.01], [125.99,22.43], [138.02,27.36], [113.02,32.62]],
       }

# 题干 写一些
# 给出交易时间数据，dates，给出可转债时间序列数据字典，key为可转债代码，value为时间序列数据
# 对于时间序列数据，每条元素对应dates的时间，且每条元素格式为【收盘价，转股溢价率】
# 双低策略定义为。。。，选双低前二作为持仓！
# 求出双低策略下，每个日期的选股，以及四个交易日后的最终收益 （也可考每周收益）

# %%
# 提示框架
for date_no in range(len(dates)):
    # 在此区域写出每个交易日的选股
    
    
    
    
    
    if date_no >= 1:
        # 在此区域写出计算每个交易日的持仓收益
